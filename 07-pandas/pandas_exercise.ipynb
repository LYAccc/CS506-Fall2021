# %% [markdown]
# <font size="8"> Introduction to Pandas </font>

# %% [markdown]
# <font size="5"> Import libraries </font>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <font size="5"> Initializing instances in Pandas </font>

# %%
df = pd.DataFrame({'Name': ['Elaine', 'Josh', 'Lin', 'Naho', 'Steve', 'Charles'],
                   'Age': [44, 17, 64, 33, 45, 25],
                   'Salary': [7000, 5800, 7900, 5600, 6700, 5900],
                   'Group': ['MA', 'NW', 'NM', 'WA', 'PA', 'TX']})

# %%
df
# Out:
#       Name  Age  Salary Group
# 0   Elaine   44    7000    MA
# 1     Josh   17    5800    NW
# 2      Lin   64    7900    NM
# 3     Naho   33    5600    WA
# 4    Steve   45    6700    PA
# 5  Charles   25    5900    TX

# %% [markdown]
# <font size="5"> Overview of the dataframe </font>

# %%
# check top rows
print(df.head())
# Out:
#      Name  Age  Salary Group
# 0  Elaine   44    7000    MA
# 1    Josh   17    5800    NW
# 2     Lin   64    7900    NM
# 3    Naho   33    5600    WA
# 4   Steve   45    6700    PA

# %%
# check bottom rows
print(df.tail(3))
# Out:
#       Name  Age  Salary Group
# 3     Naho   33    5600    WA
# 4    Steve   45    6700    PA
# 5  Charles   25    5900    TX

# %%
# check index
print(df.index)
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
# check attribute names
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Salary', 'Group'], dtype='object')

# %%
# check sum 
print(df.sum())
# Out:
# Name      ElaineJoshLinNahoSteveCharles
# Age                                 228
# Salary                            38900
# Group                      MANWNMWAPATX
# dtype: object

# %%
# check mean
print(df.mean())
# Out:
# Age         38.000000
# Salary    6483.333333
# dtype: float64

# %% [markdown]
# <font size="5"> Basic operations </font>

# %%
# Taking subsets of columns
print(df['Age'])
# Out:
# 0    44
# 1    17
# 2    64
# 3    33
# 4    45
# 5    25
# Name: Age, dtype: int64

# %%
# Selecting rows with index
print(df[2:4])
# Out:
#    Name  Age  Salary Group
# 2   Lin   64    7900    NM
# 3  Naho   33    5600    WA

# %%
# Selecting rows and columns together with value
print(df.loc[1:4, ['Salary','Name']])
# Out:
#    Salary   Name
# 1    5800   Josh
# 2    7900    Lin
# 3    5600   Naho
# 4    6700  Steve

# %%
# Selecting rows and columns together with index
print(df.iloc[1:4, 2:4])
# Out:
#    Salary Group
# 1    5800    NW
# 2    7900    NM
# 3    5600    WA

# %%
# Selecting rows and columns together with index
print(df.iloc[[1,3,4], [1,3]])
# Out:
#    Age Group
# 1   17    NW
# 3   33    WA
# 4   45    PA

# %%
# Selecting with query
print(df[df['Salary']>100])
# Out:
#       Name  Age  Salary Group
# 0   Elaine   44    7000    MA
# 1     Josh   17    5800    NW
# 2      Lin   64    7900    NM
# 3     Naho   33    5600    WA
# 4    Steve   45    6700    PA
# 5  Charles   25    5900    TX

# %%
# Selecting with multiple queries
print(df[(df['Salary']>100) & (df['Age']>30)])
# Out:
#      Name  Age  Salary Group
# 0  Elaine   44    7000    MA
# 2     Lin   64    7900    NM
# 3    Naho   33    5600    WA
# 4   Steve   45    6700    PA

# %%
# sort according to specific attribute
print(df.sort_values(by='Age', ascending=False))
# Out:
#       Name  Age  Salary Group
# 2      Lin   64    7900    NM
# 4    Steve   45    6700    PA
# 0   Elaine   44    7000    MA
# 3     Naho   33    5600    WA
# 5  Charles   25    5900    TX
# 1     Josh   17    5800    NW

# %%
# appending another DataFrame to the old one
df2 = pd.DataFrame({'Name': ['Chris', 'Peter'],
                   'Age': [18, np.nan],
                   'Salary': [np.nan, 9],
                   'Group': ['NV', 'FL']})

df_new = df.append(df2, ignore_index=True)
df_new
# Out:
#       Name   Age  Salary Group
# 0   Elaine  44.0  7000.0    MA
# 1     Josh  17.0  5800.0    NW
# 2      Lin  64.0  7900.0    NM
# 3     Naho  33.0  5600.0    WA
# 4    Steve  45.0  6700.0    PA
# 5  Charles  25.0  5900.0    TX
# 6    Chris  18.0     NaN    NV
# 7    Peter   NaN     9.0    FL

# %%
# filter out NaN values
print(df_new.dropna(how='any', subset=['Salary']))
# Out:
#       Name   Age  Salary Group
# 0   Elaine  44.0  7000.0    MA
# 1     Josh  17.0  5800.0    NW
# 2      Lin  64.0  7900.0    NM
# 3     Naho  33.0  5600.0    WA
# 4    Steve  45.0  6700.0    PA
# 5  Charles  25.0  5900.0    TX
# 7    Peter   NaN     9.0    FL

# %%
# replace NaN values with specified value
print(df_new.fillna(value='None'))
# Out:
#       Name   Age Salary Group
# 0   Elaine    44   7000    MA
# 1     Josh    17   5800    NW
# 2      Lin    64   7900    NM
# 3     Naho    33   5600    WA
# 4    Steve    45   6700    PA
# 5  Charles    25   5900    TX
# 6    Chris    18   None    NV
# 7    Peter  None      9    FL

# %%
# export as numpy array
print(df_new.values)
# Out:
# [['Elaine' 44.0 7000.0 'MA']
#  ['Josh' 17.0 5800.0 'NW']
#  ['Lin' 64.0 7900.0 'NM']
#  ['Naho' 33.0 5600.0 'WA']
#  ['Steve' 45.0 6700.0 'PA']
#  ['Charles' 25.0 5900.0 'TX']
#  ['Chris' 18.0 nan 'NV']
#  ['Peter' nan 9.0 'FL']]

# %%
df_left = pd.DataFrame({'Name': ['Elaine', 'Josh', 'Lin', 'Naho', 'Steve', 'Charles'],
                   'Age': [44, 17, 64, 33, 45, 25],
                   'Salary': [7000, 5800, 7900, 5600, 6700, 5900],
                   'Group': ['MA', 'NW', 'NM', 'WA', 'PA', 'TX']})
df_right = pd.DataFrame({'Name': ['Josh', 'Lin', 'Steve', 'Charles', 'Chris', 'Pan'],
                   'Location': ["Boston", "DC", "Seattle", "San Jose", "New York", "Denver"],
                   'Team': ["A", "A", "C", "B", "D", "C"]})

print(df_left)
print(df_right)
# Out:
#       Name  Age  Salary Group
# 0   Elaine   44    7000    MA
# 1     Josh   17    5800    NW
# 2      Lin   64    7900    NM
# 3     Naho   33    5600    WA
# 4    Steve   45    6700    PA
# 5  Charles   25    5900    TX
#       Name  Location Team
# 0     Josh    Boston    A
# 1      Lin        DC    A
# 2    Steve   Seattle    C
# 3  Charles  San Jose    B
# 4    Chris  New York    D
# 5      Pan    Denver    C

# %%
# Merging two tables using intersection of keys from both frames
pd.merge(df_left, df_right,how="inner")
# Out:
#       Name  Age  Salary Group  Location Team
# 0     Josh   17    5800    NW    Boston    A
# 1      Lin   64    7900    NM        DC    A
# 2    Steve   45    6700    PA   Seattle    C
# 3  Charles   25    5900    TX  San Jose    B

# %%
# Merging two tables using union of keys from both frames
pd.merge(df_left, df_right,how="outer")
# Out:
#       Name   Age  Salary Group  Location Team
# 0   Elaine  44.0  7000.0    MA       NaN  NaN
# 1     Josh  17.0  5800.0    NW    Boston    A
# 2      Lin  64.0  7900.0    NM        DC    A
# 3     Naho  33.0  5600.0    WA       NaN  NaN
# 4    Steve  45.0  6700.0    PA   Seattle    C
# 5  Charles  25.0  5900.0    TX  San Jose    B
# 6    Chris   NaN     NaN   NaN  New York    D
# 7      Pan   NaN     NaN   NaN    Denver    C

# %%
# Merging two tables using keys from left frame only
pd.merge(df_left, df_right,how="left")
# Out:
#       Name  Age  Salary Group  Location Team
# 0   Elaine   44    7000    MA       NaN  NaN
# 1     Josh   17    5800    NW    Boston    A
# 2      Lin   64    7900    NM        DC    A
# 3     Naho   33    5600    WA       NaN  NaN
# 4    Steve   45    6700    PA   Seattle    C
# 5  Charles   25    5900    TX  San Jose    B

# %%
# Merging two tables using keys from right frame only
pd.merge(df_left, df_right,how="right")
# Out:
#       Name   Age  Salary Group  Location Team
# 0     Josh  17.0  5800.0    NW    Boston    A
# 1      Lin  64.0  7900.0    NM        DC    A
# 2    Steve  45.0  6700.0    PA   Seattle    C
# 3  Charles  25.0  5900.0    TX  San Jose    B
# 4    Chris   NaN     NaN   NaN  New York    D
# 5      Pan   NaN     NaN   NaN    Denver    C

# %%
# Group frame with specified column and get the mean values for each "cluster"
(pd.merge(df_left, df_right,how="outer").groupby(["Team"]).mean())
# Out:
#        Age  Salary
# Team
# A     40.5  6850.0
# B     25.0  5900.0
# C     45.0  6700.0
# D      NaN     NaN

# %%
# Visualize 
df_left.plot(x="Name", y=["Age","Salary"], kind='bar');

# %% [markdown]
# <font size="5"> Challenge </font>

# %% [markdown]
# Implement a function process() that given the path to a CSV file as input, select those entries with a valid license (not NaN), room type of Private room, price less than or equal to 80, minimum nights less than or equal to 2, number of reviewers more than or equal to 500, or those with a valid license (not NaN), a room type of Entire home/apt, price less than or equal to 100, minimum nights less than or equal to 1, number of reviewers more than or equal to 100, and finally present the result sorted according to latitude and then longitude in an ascending order and with only columns of id, latitude, longitude, room_type, price and availability_365.

# %%
def process(path):
    df = pd.read_csv(path)
    df = df.dropna(how='any', subset=['license'])
    df_private = df[(df['room_type'] == 'Private room') & (df['price'] <= 80) & (df['minimum_nights'] <= 2) &(df['number_of_reviews'] >= 500)]
    df_Entire = df[(df['room_type'] == 'Entire home/apt')&(df['price'] <= 100)&(df['minimum_nights'] <= 1)]
    df_new =  df_private.append(df_Entire,ignore_index=True)[['id','latitude','longitude','room_type','price','availability_365']]
    return df_new.sort_values(by = ['latitude','longitude'],ascending = True).reset_index(drop = True)
df = process('listings.csv')
df
# Out:
#           id   latitude  longitude        room_type  price  availability_365
# 0   23770069  52.294780   4.972310  Entire home/apt     88               128
# 1   41394232  52.297580   4.975860  Entire home/apt    100                 0
# 2   42112141  52.329440   4.858430  Entire home/apt     60                25
# 3    3508800  52.333100   4.903000     Private room     49                67
# 4   29212801  52.341880   4.920730  Entire home/apt     79               207
# 5   15110564  52.343890   4.898870  Entire home/apt     96                20
# 6   49341793  52.345520   4.811080  Entire home/apt     96                 3
# 7   40625996  52.347140   4.900520  Entire home/apt     91               203
# 8   49688654  52.348410   4.863020  Entire home/apt     90                 9
# 9   25485617  52.350880   4.849720  Entire home/apt    100                 0
# 10  49585464  52.351850   4.896130  Entire home/apt     95               296
# 11  50800575  52.352160   4.907970  Entire home/apt     80               224
# 12  44550045  52.352630   4.898870  Entire home/apt     92                 0
# 13  17774718  52.353180   4.846890  Entire home/apt     89               312
# 14   7276869  52.354920   4.898650     Private room     69                33
# 15   5848732  52.355930   4.898880  Entire home/apt     84                 0
# 16   1247334  52.355960   4.903390     Private room     78                 0
# 17  31095874  52.356050   4.921210  Entire home/apt     78                 4
# 18   7190115  52.356980   4.900150     Private room     71                21
# 19  29156993  52.358040   4.903620  Entire home/apt     68                 0
# 20   7571471  52.358730   4.855080     Private room     65               282
# 21   8299748  52.359370   4.854430  Entire home/apt     95                 0
# 22  50515860  52.359470   4.914480  Entire home/apt     91                 0
# 23  12205686  52.361310   4.926670  Entire home/apt     93                 0
# 24  40335248  52.362540   4.932090  Entire home/apt     95               123
# 25  31018071  52.363180   4.905140  Entire home/apt     84                34
# 26  19385476  52.363860   4.942930  Entire home/apt    100                 0
# 27  50167653  52.363870   4.938070  Entire home/apt     89                15
# 28  22458546  52.365380   4.851950  Entire home/apt     85                 0
# 29   1008223  52.365610   4.840380     Private room     51               324
# 30  44456510  52.366520   4.866660  Entire home/apt     78                 4
# 31   7455430  52.368650   4.852640  Entire home/apt     79                 0
# 32  34349941  52.368860   4.880440  Entire home/apt     83                15
# 33  22563427  52.369180   4.880470  Entire home/apt     94                44
# 34  26560199  52.370990   4.971700  Entire home/apt     80                 0
# 35  22607752  52.371590   4.860860  Entire home/apt     75                 0
# 36  50774658  52.372270   4.970490  Entire home/apt     67                 2
# 37   4449764  52.373130   4.951460     Private room     69                 0
# 38  47371801  52.375500   4.893180  Entire home/apt     46                 0
# 39  48875679  52.375510   4.860090  Entire home/apt     99                34
# 40  45970132  52.376880   4.895930  Entire home/apt     77                 0
# 41   8743652  52.378180   4.856460  Entire home/apt     89                 6
# 42  31731136  52.378250   4.892390  Entire home/apt     78                57
# 43    608432  52.381996   4.888583     Private room     56                42
# 44  50369122  52.382100   4.867600  Entire home/apt     99                 5
# 45  50848503  52.382130   4.848830  Entire home/apt     75                12
# 46  28170875  52.383880   4.787870  Entire home/apt     99               312
# 47  28171967  52.383880   4.787870  Entire home/apt    100               292
# 48  29914252  52.383880   4.787870  Entire home/apt     83               245
# 49  45681269  52.383880   4.787870  Entire home/apt    100               323
# 50  50021981  52.383980   4.881090  Entire home/apt     94               322
# 51  43705764  52.384430   4.881080  Entire home/apt     45               196
# 52  50123424  52.384950   4.875780  Entire home/apt    100                 0
# 53  39752904  52.385950   4.878790  Entire home/apt    100                33
# 54  10432232  52.386530   4.915340     Private room     75               132
# 55  50767325  52.397510   4.938250  Entire home/apt     90               219
# 56  36324929  52.398350   4.906910  Entire home/apt     90                 0
# 57  51318689  52.406670   4.917540  Entire home/apt    100                 9
# 58  36096452  52.418810   4.905870  Entire home/apt     80               310
